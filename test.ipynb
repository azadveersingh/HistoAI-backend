# %%
import pandas as pd

# Read a CSV file
df = pd.read_csv("app/uploads/books/68a74de51155a39d312c8e1c/Data Extraction/384927469-History-of-India-pdf.csv")

# Show the first 5 rows
df.tail()
# Out:
#      Chunk ID                                         Text Chunk  \
# 551       552  Tagore, Dwarkanath (entrepreneur) 232\nTaila (...
# 552       553  Telugu language 15, 179, 246, 301\ntemples\nin...
# 553       554  (Hun leader) 90–1\nTosali 65\ntrade, internati...
# 554       555  Udaipur 9, 129, 140, 157\nUdayaditya 130\nUday...
# 555       556  Vainyagupta (king) 90\nVaishali 53–4\nVaishnav...
#
#                                             Source URL
# 551  books/68a74de51155a39d312c8e1c/384927469-Histo...
# 552  books/68a74de51155a39d312c8e1c/384927469-Histo...
# 553  books/68a74de51155a39d312c8e1c/384927469-Histo...
# 554  books/68a74de51155a39d312c8e1c/384927469-Histo...
# 555  books/68a74de51155a39d312c8e1c/384927469-Histo...
