# %%
import pandas as pd

# Read a CSV file
df = pd.read_csv("app/uploads/books/68a2c3eb9cde9e790be53491/Data Extraction/6-Page_1857_Essay_from_economics_and_political_weekly.csv")

# Show the first 5 rows
df.head()
# Out:
#    chunk_id                                         chunk_text  \
# 0         1  185 \nESSAYS FROM \n1/vOMIC AND POLITICAL WEEK...
# 1         2  What is interesting about the history of 1857 ...
# 2         3  Recently, Tony \nBalantyne has shown that even...
# 3         4  Rumours spread quickly that the \ncartridge wa...
# 4         5  "An accidental hero", as Rudrangshu Mukehrjee ...
#
#                                           source_url
# 0  /home/cair3/Desktop/HistoAI/HistoAI-backend/ap...
# 1  /home/cair3/Desktop/HistoAI/HistoAI-backend/ap...
# 2  /home/cair3/Desktop/HistoAI/HistoAI-backend/ap...
# 3  /home/cair3/Desktop/HistoAI/HistoAI-backend/ap...
# 4  /home/cair3/Desktop/HistoAI/HistoAI-backend/ap...
